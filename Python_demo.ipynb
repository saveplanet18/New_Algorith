# %%
Manjunath_kannur = "author spoon middle banner glide camp cross easily joy online disorder cruel cool rude roof wood chunk pony alley mobile strategy tiger floor trumpet"
wallet_address = 'GDHIVGGA2IQ4T5LY2FJB7Q2VMEF4TQPB3UBDKBTN5YOXYV2QUAYBBC6I'

Manjunath_kannur_another = "denial village table oak curious voyage wrap flip repeat junk sibling kiss collect section icon vocal rate alarm code lemon gloom then vessel tortoise"

Timestop = "33f59iku3rwfCPm7Yyjsaneezz2tqXMCiDyi8zZk5qouWgW9niKKzCEmsUQYB5TTP9pouZhE2p4cRXb1Y4iZnpHL"
Bee_love = "833bce46904e8c278910ef70f502eeb56b49b029721011fd4f197d22d65938d3"

Amma_Kannur = "earth wisdom flag usage reject raccoon setup resemble excess shield choice thrive ridge typical crumble eye basic hazard mistake equal life quantum depend catch"

Indira_meti = "tide stumble give soda beyond clarify coach until vault inquiry found oak include toe title genre actor issue hungry paddle sign picnic ticket judge"

BNB_wallent_name = "snake room cancel sausage urge spin liar fog salute just drip advice" 

Malu_kannur = "fresh bench brain thumb differ copy arrow logic sound alter receive woman fancy frame cake pencil upgrade suit biology denial zoo base south strike"

Manjunath_Kattimani = "group sight sunny cancel canoe assist merry march repeat fly marble above atom outer warm patient rail visual scale wedding decade column endorse animal"

Muttu_Bhajantri = "diary design glance radio airport grace chaos spy size relief glance duck cattle profit frown subway word obscure food mass gap shadow run airport"

Sohail_Chapparband = "mimic bind rack swear afraid call stuff regret glass arena busy spray solar blue speak control inch retreat busy produce rate middle when mother"

Kamala_marali = "tuition gauge steak annual must you label fun fix tomato scorpion misery vague tragic sad unfold garbage autumn unhappy mosquito nurse topple various birth"

Siddu_gurikar = "beef seminar ahead pepper reward chunk anger silly live twist essence caution tornado very chief entire elder welcome wait ticket tip mistake fatigue rug"

Sindur_Kattimani = "ski vague song tennis elevator moment leaf sweet upper badge gate police rib then master neck breeze art addict giggle uncle derive young race"

Bhimappa_mygeri = "gap tourist suspect rude huge chest bounce bench cousin like switch enhance exhaust surge panic sketch icon diary news muffin put cart vapor atom"

Bassu_Mygeri = "retreat extra rather lift defy surge wreck exclude funny reason survey among scale meadow change castle heavy clip fragile token cry tongue random ladder"

Rajeswari_nagavi = "dream also endorse mesh road grass vacuum violin method crime unhappy inform helmet hen fluid save busy modify fatal sell erode feature mutual twelve"

Shivanadapattanada = "census patch eight aim old crater damp minor lecture north once attract chuckle cricket whale museum good piano chronic hawk icon divert fury crater"


Aslam_Naikodi = "hand forum praise fun regret champion film forward click glass remind invest slab awkward arctic time mechanic kiwi weasel sound vault myself into rescue"

Gangadrar_barmagouda = "ship arrest cliff pill link deny parrot yellow obvious actual luxury topic shaft valid jealous stuff core edge method bar shadow dish rain such"

Devaraj_Dk_Meti = "tide stumble give soda beyond clarify coach until vault inquiry found oak include toe title genre actor issue hungry paddle sign picnic ticket judge"

Devaraj_Dk_Meti_another = "author spoon middle banner glide camp cross easily joy online disorder cruel cool rude roof wood chunk pony alley mobile strategy tiger floor trumpet"

Mudaku_bajantri = "hat vivid obey armed concert indoor supreme shaft fatal scheme unusual inject mesh fossil property canal easy reform foster escape device renew swing employ"

Suresh_narasanagi = "wage hockey gallery sense coil way style tonight image ivory visual fitness file lecture exercise future skate fashion light deny tennis drastic grace step"

Ganesh_kannur = "claim snap battle approve adjust remind better bus lottery quit fiscal two flip moment naive buddy worry loyal derive awesome person worth super reflect"

Chinnu_naranasangi = "ripple amazing field identify chalk dash surprise forum confirm next tragic misery soul comfort pilot flame abuse hundred vibrant sugar drum speed conduct drive"

Laxman_Yalagod = "obvious stay chaos dress veteran party praise boy wage axis regular token slam opera benefit run fatigue embrace myth opera skirt cool upset brush"

Kumar_damanal = "eternal design key weekend tower rival color dish approve easily bid furnace shield october clog flip educate abuse control sweet belt digital vessel render"

vvinodpattanad = "noble head tribe come safe oppose rapid bird verb inherit throw vague ahead burst scorpion silver lucky ten sing funny unfold memory stage million"

Soyabakthar_talikoti = "illness bird better neither portion divorce omit peasant advance glory brass bench seven inquiry barrel hint bag undo cook smile meat flower exercise primary"

Prakash_basarkoda = "tired merit drip before suggest rubber skin potato physical wrong extend margin regular extend sort distance cube fragile sausage observe hamster future pizza minute"

Shada_bangargunda = "affair element grunt leaf vacant advice bottom glide bright tail enroll impulse seminar female upgrade resist emotion scale artist cradle milk crater include unfair"

Pradanppa_yalagi = "simple olympic tiny surround forward hold scale brisk match negative thank guess glove safe aunt army custom cement dutch mention subway matrix perfect mistake"

Maibu_naikodi = "parade silk swarm april moment control antenna scrap pelican helmet angle praise pulse leave welcome beef smile pet mesh bench pelican attitude rug chef"

Maibu_chapparabanda = "wild scrub phone screen mean arrange mesh decline fame food hole then fall dry banner high notable person ancient vital fox swap garbage picnic"

Muttanna_vaidya = "amused author impact super tomorrow zebra ivory evil chronic century horse disorder goose fork hope task radio acoustic enemy inmate dance lab spend quiz"

ಪ್ರಭುಲಿಂಗ ಹಂದ್ರಾಳ = "cycle require wisdom forward soft senior suspect melt surface blind fancy phone captain certain depth roast camera leisure junior service original dirt title royal"

Ambresh_kannur = "original enlist tide asset blood transfer portion myth squeeze sign volume solution learn peanut load lizard candy post field hedgehog fitness chronic midnight zone"

hullanna_mygeri = "skill pottery flush ahead common task leopard practice print dilemma game peasant shiver exist entry faith cherry velvet hand shy dignity other fabric excuse"

Mallu_narasanagi = "avocado virus tilt decade body sunset awful reopen approve lobster build load actor robust lounge drift trial then grant run cruel narrow web correct"

Raju_pidigit = "boost desk layer answer impose rally swap panther few vehicle try swear goose cable rival acquire ribbon funny matter scrap school kid fossil beauty"

Mallu_aparadhi = "space crowd tornado logic badge crunch range this detail chaos interest hold bright spray crucial tumble clarify involve bar minimum excess private joy success"


Prashant_chalami_dumma = "author spoon middle banner glide camp cross easily joy online disorder cruel cool rude roof wood chunk pony alley mobile strategy tiger floor trumpet"
